# %%
# Istalling library to calculate pytorch flops at each and every step in the model architecture.
# !pip install ptflops
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ptflops
#   Downloading ptflops-0.6.9.tar.gz (12 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.8/dist-packages (from ptflops) (1.12.1+cu113)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch->ptflops) (4.1.1)
# Building wheels for collected packages: ptflops
#   Building wheel for ptflops (setup.py) ... done
#   Created wheel for ptflops: filename=ptflops-0.6.9-py3-none-any.whl size=11712 sha256=ffbbac2eaf5568058b1aaa9cb093543641b811b423cd9b562bc65495d1a9d3a6
#   Stored in directory: /root/.cache/pip/wheels/b6/86/d5/cf62a3571b005f91cd9accefc5e10f40214538be997198afad
# Successfully built ptflops
# Installing collected packages: ptflops
# Successfully installed ptflops-0.6.9

# %%
# Importing necessary libraries
import torchvision.models as models
import torch
from ptflops import get_model_complexity_info
from torch.utils.data import dataloader
import torch
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np
import torchvision.datasets as datasets

# %%
# Loading all the three models
resnet = torch.load('resnet.pt')
shuffle_net = torch.load('shufflenet0.001.pt')
mobile_net = torch.load('mobilenet.pt')

# %%
# Function to calculate FLOPS count
def flops_calculate(model):
  with torch.cuda.device(0):
    net = model
    macs, params = get_model_complexity_info(net, (3, 224, 224), as_strings=True,
                                            print_per_layer_stat=True, verbose=True)
    print('{:<30}  {:<8}'.format('Computational complexity: ', macs))
    print('{:<30}  {:<8}'.format('Number of parameters: ', params))

# %%
flops_calculate(resnet)
# Out:
# Warning: module BasicBlock is treated as a zero-op.
# Warning: module ResNet is treated as a zero-op.
# ResNet(
#   11.69 M, 100.000% Params, 1.82 GMac, 100.000% MACs,
#   (conv1): Conv2d(9.41 k, 0.080% Params, 118.01 MMac, 6.477% MACs, 3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(128, 0.001% Params, 1.61 MMac, 0.088% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(0, 0.000% Params, 802.82 KMac, 0.044% MACs, inplace=True)
#   (maxpool): MaxPool2d(0, 0.000% Params, 802.82 KMac, 0.044% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     147.97 k, 1.266% Params, 464.83 MMac, 25.510% MACs,
#     (0): BasicBlock(
#       73.98 k, 0.633% Params, 232.42 MMac, 12.755% MACs,
#       (conv1): Conv2d(36.86 k, 0.315% Params, 115.61 MMac, 6.344% MACs, 64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, 0.001% Params, 401.41 KMac, 0.022% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(0, 0.000% Params, 401.41 KMac, 0.022% MACs, inplace=True)
#       (conv2): Conv2d(36.86 k, 0.315% Params, 115.61 MMac, 6.344% MACs, 64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, 0.001% Params, 401.41 KMac, 0.022% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       73.98 k, 0.633% Params, 232.42 MMac, 12.755% MACs,
#       (conv1): Conv2d(36.86 k, 0.315% Params, 115.61 MMac, 6.344% MACs, 64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, 0.001% Params, 401.41 KMac, 0.022% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(0, 0.000% Params, 401.41 KMac, 0.022% MACs, inplace=True)
#       (conv2): Conv2d(36.86 k, 0.315% Params, 115.61 MMac, 6.344% MACs, 64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, 0.001% Params, 401.41 KMac, 0.022% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     525.57 k, 4.496% Params, 412.45 MMac, 22.635% MACs,
#     (0): BasicBlock(
#       230.14 k, 1.969% Params, 180.63 MMac, 9.913% MACs,
#       (conv1): Conv2d(73.73 k, 0.631% Params, 57.8 MMac, 3.172% MACs, 64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, 0.002% Params, 200.7 KMac, 0.011% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(0, 0.000% Params, 200.7 KMac, 0.011% MACs, inplace=True)
#       (conv2): Conv2d(147.46 k, 1.261% Params, 115.61 MMac, 6.344% MACs, 128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, 0.002% Params, 200.7 KMac, 0.011% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         8.45 k, 0.072% Params, 6.62 MMac, 0.363% MACs,
#         (0): Conv2d(8.19 k, 0.070% Params, 6.42 MMac, 0.352% MACs, 64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, 0.002% Params, 200.7 KMac, 0.011% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       295.42 k, 2.527% Params, 231.81 MMac, 12.722% MACs,
#       (conv1): Conv2d(147.46 k, 1.261% Params, 115.61 MMac, 6.344% MACs, 128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, 0.002% Params, 200.7 KMac, 0.011% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(0, 0.000% Params, 200.7 KMac, 0.011% MACs, inplace=True)
#       (conv2): Conv2d(147.46 k, 1.261% Params, 115.61 MMac, 6.344% MACs, 128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, 0.002% Params, 200.7 KMac, 0.011% MACs, 128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     2.1 M, 17.962% Params, 411.74 MMac, 22.596% MACs,
#     (0): BasicBlock(
#       919.04 k, 7.862% Params, 180.23 MMac, 9.891% MACs,
#       (conv1): Conv2d(294.91 k, 2.523% Params, 57.8 MMac, 3.172% MACs, 128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, 0.004% Params, 100.35 KMac, 0.006% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(0, 0.000% Params, 100.35 KMac, 0.006% MACs, inplace=True)
#       (conv2): Conv2d(589.82 k, 5.046% Params, 115.61 MMac, 6.344% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, 0.004% Params, 100.35 KMac, 0.006% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         33.28 k, 0.285% Params, 6.52 MMac, 0.358% MACs,
#         (0): Conv2d(32.77 k, 0.280% Params, 6.42 MMac, 0.352% MACs, 128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, 0.004% Params, 100.35 KMac, 0.006% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       1.18 M, 10.100% Params, 231.51 MMac, 12.705% MACs,
#       (conv1): Conv2d(589.82 k, 5.046% Params, 115.61 MMac, 6.344% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, 0.004% Params, 100.35 KMac, 0.006% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(0, 0.000% Params, 100.35 KMac, 0.006% MACs, inplace=True)
#       (conv2): Conv2d(589.82 k, 5.046% Params, 115.61 MMac, 6.344% MACs, 256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, 0.004% Params, 100.35 KMac, 0.006% MACs, 256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     8.39 M, 71.806% Params, 411.39 MMac, 22.577% MACs,
#     (0): BasicBlock(
#       3.67 M, 31.422% Params, 180.03 MMac, 9.880% MACs,
#       (conv1): Conv2d(1.18 M, 10.092% Params, 57.8 MMac, 3.172% MACs, 256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(1.02 k, 0.009% Params, 50.18 KMac, 0.003% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(0, 0.000% Params, 50.18 KMac, 0.003% MACs, inplace=True)
#       (conv2): Conv2d(2.36 M, 20.183% Params, 115.61 MMac, 6.344% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(1.02 k, 0.009% Params, 50.18 KMac, 0.003% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         132.1 k, 1.130% Params, 6.47 MMac, 0.355% MACs,
#         (0): Conv2d(131.07 k, 1.121% Params, 6.42 MMac, 0.352% MACs, 256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1.02 k, 0.009% Params, 50.18 KMac, 0.003% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       4.72 M, 40.384% Params, 231.36 MMac, 12.697% MACs,
#       (conv1): Conv2d(2.36 M, 20.183% Params, 115.61 MMac, 6.344% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(1.02 k, 0.009% Params, 50.18 KMac, 0.003% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(0, 0.000% Params, 50.18 KMac, 0.003% MACs, inplace=True)
#       (conv2): Conv2d(2.36 M, 20.183% Params, 115.61 MMac, 6.344% MACs, 512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(1.02 k, 0.009% Params, 50.18 KMac, 0.003% MACs, 512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(0, 0.000% Params, 25.09 KMac, 0.001% MACs, output_size=(1, 1))
#   (fc): Linear(513.0 k, 4.389% Params, 513.0 KMac, 0.028% MACs, in_features=512, out_features=1000, bias=True)
# )
# Computational complexity:       1.82 GMac
# Number of parameters:           11.69 M

# %%
flops_calculate(shuffle_net)
# Out:
# Warning: module InvertedResidual is treated as a zero-op.
# Warning: module ShuffleNetV2 is treated as a zero-op.
# ShuffleNetV2(
#   2.28 M, 100.000% Params, 150.6 MMac, 100.000% MACs,
#   (conv1): Sequential(
#     696, 0.031% Params, 9.03 MMac, 5.997% MACs,
#     (0): Conv2d(648, 0.028% Params, 8.13 MMac, 5.397% MACs, 3, 24, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(48, 0.002% Params, 602.11 KMac, 0.400% MACs, 24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(0, 0.000% Params, 301.06 KMac, 0.200% MACs, inplace=True)
#   )
#   (maxpool): MaxPool2d(0, 0.000% Params, 301.06 KMac, 0.200% MACs, kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (stage2): Sequential(
#     30.19 k, 1.325% Params, 27.76 MMac, 18.435% MACs,
#     (0): InvertedResidual(
#       7.4 k, 0.325% Params, 9.62 MMac, 6.388% MACs,
#       (branch1): Sequential(
#         1.77 k, 0.078% Params, 1.43 MMac, 0.953% MACs,
#         (0): Conv2d(216, 0.009% Params, 169.34 KMac, 0.112% MACs, 24, 24, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=24, bias=False)
#         (1): BatchNorm2d(48, 0.002% Params, 37.63 KMac, 0.025% MACs, 24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): Conv2d(1.39 k, 0.061% Params, 1.09 MMac, 0.725% MACs, 24, 58, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(116, 0.005% Params, 90.94 KMac, 0.060% MACs, 58, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(0, 0.000% Params, 45.47 KMac, 0.030% MACs, inplace=True)
#       )
#       (branch2): Sequential(
#         5.63 k, 0.247% Params, 8.18 MMac, 5.435% MACs,
#         (0): Conv2d(1.39 k, 0.061% Params, 4.37 MMac, 2.899% MACs, 24, 58, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(116, 0.005% Params, 363.78 KMac, 0.242% MACs, 58, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(0, 0.000% Params, 181.89 KMac, 0.121% MACs, inplace=True)
#         (3): Conv2d(522, 0.023% Params, 409.25 KMac, 0.272% MACs, 58, 58, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=58, bias=False)
#         (4): BatchNorm2d(116, 0.005% Params, 90.94 KMac, 0.060% MACs, 58, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(3.36 k, 0.148% Params, 2.64 MMac, 1.751% MACs, 58, 58, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(116, 0.005% Params, 90.94 KMac, 0.060% MACs, 58, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(0, 0.000% Params, 45.47 KMac, 0.030% MACs, inplace=True)
#       )
#     )
#     (1): InvertedResidual(
#       7.6 k, 0.333% Params, 6.05 MMac, 4.016% MACs,
#       (branch1): Sequential(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       (branch2): Sequential(
#         7.6 k, 0.333% Params, 6.05 MMac, 4.016% MACs,
#         (0): Conv2d(3.36 k, 0.148% Params, 2.64 MMac, 1.751% MACs, 58, 58, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(116, 0.005% Params, 90.94 KMac, 0.060% MACs, 58, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(0, 0.000% Params, 45.47 KMac, 0.030% MACs, inplace=True)
#         (3): Conv2d(522, 0.023% Params, 409.25 KMac, 0.272% MACs, 58, 58, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=58, bias=False)
#         (4): BatchNorm2d(116, 0.005% Params, 90.94 KMac, 0.060% MACs, 58, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(3.36 k, 0.148% Params, 2.64 MMac, 1.751% MACs, 58, 58, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(116, 0.005% Params, 90.94 KMac, 0.060% MACs, 58, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(0, 0.000% Params, 45.47 KMac, 0.030% MACs, inplace=True)
#       )
#     )
#     (2): InvertedResidual(
#       7.6 k, 0.333% Params, 6.05 MMac, 4.016% MACs,
#       (branch1): Sequential(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       (branch2): Sequential(
#         7.6 k, 0.333% Params, 6.05 MMac, 4.016% MACs,
#         (0): Conv2d(3.36 k, 0.148% Params, 2.64 MMac, 1.751% MACs, 58, 58, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(116, 0.005% Params, 90.94 KMac, 0.060% MACs, 58, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(0, 0.000% Params, 45.47 KMac, 0.030% MACs, inplace=True)
#         (3): Conv2d(522, 0.023% Params, 409.25 KMac, 0.272% MACs, 58, 58, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=58, bias=False)
#         (4): BatchNorm2d(116, 0.005% Params, 90.94 KMac, 0.060% MACs, 58, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(3.36 k, 0.148% Params, 2.64 MMac, 1.751% MACs, 58, 58, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(116, 0.005% Params, 90.94 KMac, 0.060% MACs, 58, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(0, 0.000% Params, 45.47 KMac, 0.030% MACs, inplace=True)
#       )
#     )
#     (3): InvertedResidual(
#       7.6 k, 0.333% Params, 6.05 MMac, 4.016% MACs,
#       (branch1): Sequential(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       (branch2): Sequential(
#         7.6 k, 0.333% Params, 6.05 MMac, 4.016% MACs,
#         (0): Conv2d(3.36 k, 0.148% Params, 2.64 MMac, 1.751% MACs, 58, 58, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(116, 0.005% Params, 90.94 KMac, 0.060% MACs, 58, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(0, 0.000% Params, 45.47 KMac, 0.030% MACs, inplace=True)
#         (3): Conv2d(522, 0.023% Params, 409.25 KMac, 0.272% MACs, 58, 58, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=58, bias=False)
#         (4): BatchNorm2d(116, 0.005% Params, 90.94 KMac, 0.060% MACs, 58, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(3.36 k, 0.148% Params, 2.64 MMac, 1.751% MACs, 58, 58, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(116, 0.005% Params, 90.94 KMac, 0.060% MACs, 58, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(0, 0.000% Params, 45.47 KMac, 0.030% MACs, inplace=True)
#       )
#     )
#   )
#   (stage3): Sequential(
#     244.18 k, 10.716% Params, 56.36 MMac, 37.426% MACs,
#     (0): InvertedResidual(
#       43.62 k, 1.914% Params, 16.73 MMac, 11.111% MACs,
#       (branch1): Sequential(
#         14.96 k, 0.657% Params, 2.96 MMac, 1.963% MACs,
#         (0): Conv2d(1.04 k, 0.046% Params, 204.62 KMac, 0.136% MACs, 116, 116, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=116, bias=False)
#         (1): BatchNorm2d(232, 0.010% Params, 45.47 KMac, 0.030% MACs, 116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): Conv2d(13.46 k, 0.591% Params, 2.64 MMac, 1.751% MACs, 116, 116, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(232, 0.010% Params, 45.47 KMac, 0.030% MACs, 116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(0, 0.000% Params, 22.74 KMac, 0.015% MACs, inplace=True)
#       )
#       (branch2): Sequential(
#         28.65 k, 1.257% Params, 13.78 MMac, 9.149% MACs,
#         (0): Conv2d(13.46 k, 0.591% Params, 10.55 MMac, 7.005% MACs, 116, 116, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(232, 0.010% Params, 181.89 KMac, 0.121% MACs, 116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(0, 0.000% Params, 90.94 KMac, 0.060% MACs, inplace=True)
#         (3): Conv2d(1.04 k, 0.046% Params, 204.62 KMac, 0.136% MACs, 116, 116, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=116, bias=False)
#         (4): BatchNorm2d(232, 0.010% Params, 45.47 KMac, 0.030% MACs, 116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(13.46 k, 0.591% Params, 2.64 MMac, 1.751% MACs, 116, 116, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(232, 0.010% Params, 45.47 KMac, 0.030% MACs, 116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(0, 0.000% Params, 22.74 KMac, 0.015% MACs, inplace=True)
#       )
#     )
#     (1): InvertedResidual(
#       28.65 k, 1.257% Params, 5.66 MMac, 3.759% MACs,
#       (branch1): Sequential(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       (branch2): Sequential(
#         28.65 k, 1.257% Params, 5.66 MMac, 3.759% MACs,
#         (0): Conv2d(13.46 k, 0.591% Params, 2.64 MMac, 1.751% MACs, 116, 116, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(232, 0.010% Params, 45.47 KMac, 0.030% MACs, 116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(0, 0.000% Params, 22.74 KMac, 0.015% MACs, inplace=True)
#         (3): Conv2d(1.04 k, 0.046% Params, 204.62 KMac, 0.136% MACs, 116, 116, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=116, bias=False)
#         (4): BatchNorm2d(232, 0.010% Params, 45.47 KMac, 0.030% MACs, 116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(13.46 k, 0.591% Params, 2.64 MMac, 1.751% MACs, 116, 116, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(232, 0.010% Params, 45.47 KMac, 0.030% MACs, 116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(0, 0.000% Params, 22.74 KMac, 0.015% MACs, inplace=True)
#       )
#     )
#     (2): InvertedResidual(
#       28.65 k, 1.257% Params, 5.66 MMac, 3.759% MACs,
#       (branch1): Sequential(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       (branch2): Sequential(
#         28.65 k, 1.257% Params, 5.66 MMac, 3.759% MACs,
#         (0): Conv2d(13.46 k, 0.591% Params, 2.64 MMac, 1.751% MACs, 116, 116, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(232, 0.010% Params, 45.47 KMac, 0.030% MACs, 116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(0, 0.000% Params, 22.74 KMac, 0.015% MACs, inplace=True)
#         (3): Conv2d(1.04 k, 0.046% Params, 204.62 KMac, 0.136% MACs, 116, 116, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=116, bias=False)
#         (4): BatchNorm2d(232, 0.010% Params, 45.47 KMac, 0.030% MACs, 116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(13.46 k, 0.591% Params, 2.64 MMac, 1.751% MACs, 116, 116, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(232, 0.010% Params, 45.47 KMac, 0.030% MACs, 116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(0, 0.000% Params, 22.74 KMac, 0.015% MACs, inplace=True)
#       )
#     )
#     (3): InvertedResidual(
#       28.65 k, 1.257% Params, 5.66 MMac, 3.759% MACs,
#       (branch1): Sequential(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       (branch2): Sequential(
#         28.65 k, 1.257% Params, 5.66 MMac, 3.759% MACs,
#         (0): Conv2d(13.46 k, 0.591% Params, 2.64 MMac, 1.751% MACs, 116, 116, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(232, 0.010% Params, 45.47 KMac, 0.030% MACs, 116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(0, 0.000% Params, 22.74 KMac, 0.015% MACs, inplace=True)
#         (3): Conv2d(1.04 k, 0.046% Params, 204.62 KMac, 0.136% MACs, 116, 116, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=116, bias=False)
#         (4): BatchNorm2d(232, 0.010% Params, 45.47 KMac, 0.030% MACs, 116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(13.46 k, 0.591% Params, 2.64 MMac, 1.751% MACs, 116, 116, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(232, 0.010% Params, 45.47 KMac, 0.030% MACs, 116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(0, 0.000% Params, 22.74 KMac, 0.015% MACs, inplace=True)
#       )
#     )
#     (4): InvertedResidual(
#       28.65 k, 1.257% Params, 5.66 MMac, 3.759% MACs,
#       (branch1): Sequential(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       (branch2): Sequential(
#         28.65 k, 1.257% Params, 5.66 MMac, 3.759% MACs,
#         (0): Conv2d(13.46 k, 0.591% Params, 2.64 MMac, 1.751% MACs, 116, 116, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(232, 0.010% Params, 45.47 KMac, 0.030% MACs, 116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(0, 0.000% Params, 22.74 KMac, 0.015% MACs, inplace=True)
#         (3): Conv2d(1.04 k, 0.046% Params, 204.62 KMac, 0.136% MACs, 116, 116, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=116, bias=False)
#         (4): BatchNorm2d(232, 0.010% Params, 45.47 KMac, 0.030% MACs, 116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(13.46 k, 0.591% Params, 2.64 MMac, 1.751% MACs, 116, 116, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(232, 0.010% Params, 45.47 KMac, 0.030% MACs, 116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(0, 0.000% Params, 22.74 KMac, 0.015% MACs, inplace=True)
#       )
#     )
#     (5): InvertedResidual(
#       28.65 k, 1.257% Params, 5.66 MMac, 3.759% MACs,
#       (branch1): Sequential(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       (branch2): Sequential(
#         28.65 k, 1.257% Params, 5.66 MMac, 3.759% MACs,
#         (0): Conv2d(13.46 k, 0.591% Params, 2.64 MMac, 1.751% MACs, 116, 116, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(232, 0.010% Params, 45.47 KMac, 0.030% MACs, 116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(0, 0.000% Params, 22.74 KMac, 0.015% MACs, inplace=True)
#         (3): Conv2d(1.04 k, 0.046% Params, 204.62 KMac, 0.136% MACs, 116, 116, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=116, bias=False)
#         (4): BatchNorm2d(232, 0.010% Params, 45.47 KMac, 0.030% MACs, 116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(13.46 k, 0.591% Params, 2.64 MMac, 1.751% MACs, 116, 116, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(232, 0.010% Params, 45.47 KMac, 0.030% MACs, 116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(0, 0.000% Params, 22.74 KMac, 0.015% MACs, inplace=True)
#       )
#     )
#     (6): InvertedResidual(
#       28.65 k, 1.257% Params, 5.66 MMac, 3.759% MACs,
#       (branch1): Sequential(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       (branch2): Sequential(
#         28.65 k, 1.257% Params, 5.66 MMac, 3.759% MACs,
#         (0): Conv2d(13.46 k, 0.591% Params, 2.64 MMac, 1.751% MACs, 116, 116, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(232, 0.010% Params, 45.47 KMac, 0.030% MACs, 116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(0, 0.000% Params, 22.74 KMac, 0.015% MACs, inplace=True)
#         (3): Conv2d(1.04 k, 0.046% Params, 204.62 KMac, 0.136% MACs, 116, 116, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=116, bias=False)
#         (4): BatchNorm2d(232, 0.010% Params, 45.47 KMac, 0.030% MACs, 116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(13.46 k, 0.591% Params, 2.64 MMac, 1.751% MACs, 116, 116, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(232, 0.010% Params, 45.47 KMac, 0.030% MACs, 116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(0, 0.000% Params, 22.74 KMac, 0.015% MACs, inplace=True)
#       )
#     )
#     (7): InvertedResidual(
#       28.65 k, 1.257% Params, 5.66 MMac, 3.759% MACs,
#       (branch1): Sequential(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       (branch2): Sequential(
#         28.65 k, 1.257% Params, 5.66 MMac, 3.759% MACs,
#         (0): Conv2d(13.46 k, 0.591% Params, 2.64 MMac, 1.751% MACs, 116, 116, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(232, 0.010% Params, 45.47 KMac, 0.030% MACs, 116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(0, 0.000% Params, 22.74 KMac, 0.015% MACs, inplace=True)
#         (3): Conv2d(1.04 k, 0.046% Params, 204.62 KMac, 0.136% MACs, 116, 116, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=116, bias=False)
#         (4): BatchNorm2d(232, 0.010% Params, 45.47 KMac, 0.030% MACs, 116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(13.46 k, 0.591% Params, 2.64 MMac, 1.751% MACs, 116, 116, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(232, 0.010% Params, 45.47 KMac, 0.030% MACs, 116, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(0, 0.000% Params, 22.74 KMac, 0.015% MACs, inplace=True)
#       )
#     )
#   )
#   (stage4): Sequential(
#     501.35 k, 22.003% Params, 32.68 MMac, 21.702% MACs,
#     (0): InvertedResidual(
#       167.97 k, 7.372% Params, 16.28 MMac, 10.810% MACs,
#       (branch1): Sequential(
#         56.84 k, 2.495% Params, 2.8 MMac, 1.857% MACs,
#         (0): Conv2d(2.09 k, 0.092% Params, 102.31 KMac, 0.068% MACs, 232, 232, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=232, bias=False)
#         (1): BatchNorm2d(464, 0.020% Params, 22.74 KMac, 0.015% MACs, 232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): Conv2d(53.82 k, 2.362% Params, 2.64 MMac, 1.751% MACs, 232, 232, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(464, 0.020% Params, 22.74 KMac, 0.015% MACs, 232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(0, 0.000% Params, 11.37 KMac, 0.008% MACs, inplace=True)
#       )
#       (branch2): Sequential(
#         111.13 k, 4.877% Params, 13.48 MMac, 8.953% MACs,
#         (0): Conv2d(53.82 k, 2.362% Params, 10.55 MMac, 7.005% MACs, 232, 232, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(464, 0.020% Params, 90.94 KMac, 0.060% MACs, 232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(0, 0.000% Params, 45.47 KMac, 0.030% MACs, inplace=True)
#         (3): Conv2d(2.09 k, 0.092% Params, 102.31 KMac, 0.068% MACs, 232, 232, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=232, bias=False)
#         (4): BatchNorm2d(464, 0.020% Params, 22.74 KMac, 0.015% MACs, 232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(53.82 k, 2.362% Params, 2.64 MMac, 1.751% MACs, 232, 232, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(464, 0.020% Params, 22.74 KMac, 0.015% MACs, 232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(0, 0.000% Params, 11.37 KMac, 0.008% MACs, inplace=True)
#       )
#     )
#     (1): InvertedResidual(
#       111.13 k, 4.877% Params, 5.47 MMac, 3.631% MACs,
#       (branch1): Sequential(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       (branch2): Sequential(
#         111.13 k, 4.877% Params, 5.47 MMac, 3.631% MACs,
#         (0): Conv2d(53.82 k, 2.362% Params, 2.64 MMac, 1.751% MACs, 232, 232, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(464, 0.020% Params, 22.74 KMac, 0.015% MACs, 232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(0, 0.000% Params, 11.37 KMac, 0.008% MACs, inplace=True)
#         (3): Conv2d(2.09 k, 0.092% Params, 102.31 KMac, 0.068% MACs, 232, 232, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=232, bias=False)
#         (4): BatchNorm2d(464, 0.020% Params, 22.74 KMac, 0.015% MACs, 232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(53.82 k, 2.362% Params, 2.64 MMac, 1.751% MACs, 232, 232, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(464, 0.020% Params, 22.74 KMac, 0.015% MACs, 232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(0, 0.000% Params, 11.37 KMac, 0.008% MACs, inplace=True)
#       )
#     )
#     (2): InvertedResidual(
#       111.13 k, 4.877% Params, 5.47 MMac, 3.631% MACs,
#       (branch1): Sequential(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       (branch2): Sequential(
#         111.13 k, 4.877% Params, 5.47 MMac, 3.631% MACs,
#         (0): Conv2d(53.82 k, 2.362% Params, 2.64 MMac, 1.751% MACs, 232, 232, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(464, 0.020% Params, 22.74 KMac, 0.015% MACs, 232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(0, 0.000% Params, 11.37 KMac, 0.008% MACs, inplace=True)
#         (3): Conv2d(2.09 k, 0.092% Params, 102.31 KMac, 0.068% MACs, 232, 232, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=232, bias=False)
#         (4): BatchNorm2d(464, 0.020% Params, 22.74 KMac, 0.015% MACs, 232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(53.82 k, 2.362% Params, 2.64 MMac, 1.751% MACs, 232, 232, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(464, 0.020% Params, 22.74 KMac, 0.015% MACs, 232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(0, 0.000% Params, 11.37 KMac, 0.008% MACs, inplace=True)
#       )
#     )
#     (3): InvertedResidual(
#       111.13 k, 4.877% Params, 5.47 MMac, 3.631% MACs,
#       (branch1): Sequential(0, 0.000% Params, 0.0 Mac, 0.000% MACs, )
#       (branch2): Sequential(
#         111.13 k, 4.877% Params, 5.47 MMac, 3.631% MACs,
#         (0): Conv2d(53.82 k, 2.362% Params, 2.64 MMac, 1.751% MACs, 232, 232, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(464, 0.020% Params, 22.74 KMac, 0.015% MACs, 232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(0, 0.000% Params, 11.37 KMac, 0.008% MACs, inplace=True)
#         (3): Conv2d(2.09 k, 0.092% Params, 102.31 KMac, 0.068% MACs, 232, 232, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=232, bias=False)
#         (4): BatchNorm2d(464, 0.020% Params, 22.74 KMac, 0.015% MACs, 232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): Conv2d(53.82 k, 2.362% Params, 2.64 MMac, 1.751% MACs, 232, 232, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (6): BatchNorm2d(464, 0.020% Params, 22.74 KMac, 0.015% MACs, 232, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (7): ReLU(0, 0.000% Params, 11.37 KMac, 0.008% MACs, inplace=True)
#       )
#     )
#   )
#   (conv5): Sequential(
#     477.18 k, 20.942% Params, 23.43 MMac, 15.559% MACs,
#     (0): Conv2d(475.14 k, 20.852% Params, 23.28 MMac, 15.459% MACs, 464, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (1): BatchNorm2d(2.05 k, 0.090% Params, 100.35 KMac, 0.067% MACs, 1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(0, 0.000% Params, 50.18 KMac, 0.033% MACs, inplace=True)
#   )
#   (fc): Linear(1.02 M, 44.984% Params, 1.02 MMac, 0.681% MACs, in_features=1024, out_features=1000, bias=True)
# )
# Computational complexity:       150.6 MMac
# Number of parameters:           2.28 M

# %%
flops_calculate(mobile_net)
# Out:
# Warning: module Conv2dNormActivation is treated as a zero-op.
# Warning: module InvertedResidual is treated as a zero-op.
# Warning: module Dropout is treated as a zero-op.
# Warning: module MobileNetV2 is treated as a zero-op.
# MobileNetV2(
#   3.5 M, 100.000% Params, 320.24 MMac, 100.000% MACs,
#   (features): Sequential(
#     2.22 M, 63.451% Params, 318.96 MMac, 99.600% MACs,
#     (0): Conv2dNormActivation(
#       928, 0.026% Params, 12.04 MMac, 3.760% MACs,
#       (0): Conv2d(864, 0.025% Params, 10.84 MMac, 3.384% MACs, 3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(64, 0.002% Params, 802.82 KMac, 0.251% MACs, 32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(0, 0.000% Params, 401.41 KMac, 0.125% MACs, inplace=True)
#     )
#     (1): InvertedResidual(
#       896, 0.026% Params, 11.64 MMac, 3.635% MACs,
#       (conv): Sequential(
#         896, 0.026% Params, 11.64 MMac, 3.635% MACs,
#         (0): Conv2dNormActivation(
#           352, 0.010% Params, 4.82 MMac, 1.504% MACs,
#           (0): Conv2d(288, 0.008% Params, 3.61 MMac, 1.128% MACs, 32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#           (1): BatchNorm2d(64, 0.002% Params, 802.82 KMac, 0.251% MACs, 32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(0, 0.000% Params, 401.41 KMac, 0.125% MACs, inplace=True)
#         )
#         (1): Conv2d(512, 0.015% Params, 6.42 MMac, 2.006% MACs, 32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): BatchNorm2d(32, 0.001% Params, 401.41 KMac, 0.125% MACs, 16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (2): InvertedResidual(
#       5.14 k, 0.147% Params, 33.87 MMac, 10.576% MACs,
#       (conv): Sequential(
#         5.14 k, 0.147% Params, 33.87 MMac, 10.576% MACs,
#         (0): Conv2dNormActivation(
#           1.73 k, 0.049% Params, 22.88 MMac, 7.145% MACs,
#           (0): Conv2d(1.54 k, 0.044% Params, 19.27 MMac, 6.017% MACs, 16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(192, 0.005% Params, 2.41 MMac, 0.752% MACs, 96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(0, 0.000% Params, 1.2 MMac, 0.376% MACs, inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           1.06 k, 0.030% Params, 3.61 MMac, 1.128% MACs,
#           (0): Conv2d(864, 0.025% Params, 2.71 MMac, 0.846% MACs, 96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#           (1): BatchNorm2d(192, 0.005% Params, 602.11 KMac, 0.188% MACs, 96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(0, 0.000% Params, 301.06 KMac, 0.094% MACs, inplace=True)
#         )
#         (2): Conv2d(2.3 k, 0.066% Params, 7.23 MMac, 2.256% MACs, 96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(48, 0.001% Params, 150.53 KMac, 0.047% MACs, 24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (3): InvertedResidual(
#       8.83 k, 0.252% Params, 28.6 MMac, 8.931% MACs,
#       (conv): Sequential(
#         8.83 k, 0.252% Params, 28.6 MMac, 8.931% MACs,
#         (0): Conv2dNormActivation(
#           3.74 k, 0.107% Params, 12.19 MMac, 3.807% MACs,
#           (0): Conv2d(3.46 k, 0.099% Params, 10.84 MMac, 3.384% MACs, 24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(288, 0.008% Params, 903.17 KMac, 0.282% MACs, 144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(0, 0.000% Params, 451.58 KMac, 0.141% MACs, inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           1.58 k, 0.045% Params, 5.42 MMac, 1.692% MACs,
#           (0): Conv2d(1.3 k, 0.037% Params, 4.06 MMac, 1.269% MACs, 144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#           (1): BatchNorm2d(288, 0.008% Params, 903.17 KMac, 0.282% MACs, 144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(0, 0.000% Params, 451.58 KMac, 0.141% MACs, inplace=True)
#         )
#         (2): Conv2d(3.46 k, 0.099% Params, 10.84 MMac, 3.384% MACs, 144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(48, 0.001% Params, 150.53 KMac, 0.047% MACs, 24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (4): InvertedResidual(
#       10.0 k, 0.285% Params, 17.21 MMac, 5.374% MACs,
#       (conv): Sequential(
#         10.0 k, 0.285% Params, 17.21 MMac, 5.374% MACs,
#         (0): Conv2dNormActivation(
#           3.74 k, 0.107% Params, 12.19 MMac, 3.807% MACs,
#           (0): Conv2d(3.46 k, 0.099% Params, 10.84 MMac, 3.384% MACs, 24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(288, 0.008% Params, 903.17 KMac, 0.282% MACs, 144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(0, 0.000% Params, 451.58 KMac, 0.141% MACs, inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           1.58 k, 0.045% Params, 1.35 MMac, 0.423% MACs,
#           (0): Conv2d(1.3 k, 0.037% Params, 1.02 MMac, 0.317% MACs, 144, 144, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=144, bias=False)
#           (1): BatchNorm2d(288, 0.008% Params, 225.79 KMac, 0.071% MACs, 144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(0, 0.000% Params, 112.9 KMac, 0.035% MACs, inplace=True)
#         )
#         (2): Conv2d(4.61 k, 0.131% Params, 3.61 MMac, 1.128% MACs, 144, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, 0.002% Params, 50.18 KMac, 0.016% MACs, 32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (5): InvertedResidual(
#       14.85 k, 0.424% Params, 11.94 MMac, 3.729% MACs,
#       (conv): Sequential(
#         14.85 k, 0.424% Params, 11.94 MMac, 3.729% MACs,
#         (0): Conv2dNormActivation(
#           6.53 k, 0.186% Params, 5.27 MMac, 1.645% MACs,
#           (0): Conv2d(6.14 k, 0.175% Params, 4.82 MMac, 1.504% MACs, 32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, 0.011% Params, 301.06 KMac, 0.094% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(0, 0.000% Params, 150.53 KMac, 0.047% MACs, inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           2.11 k, 0.060% Params, 1.81 MMac, 0.564% MACs,
#           (0): Conv2d(1.73 k, 0.049% Params, 1.35 MMac, 0.423% MACs, 192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#           (1): BatchNorm2d(384, 0.011% Params, 301.06 KMac, 0.094% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(0, 0.000% Params, 150.53 KMac, 0.047% MACs, inplace=True)
#         )
#         (2): Conv2d(6.14 k, 0.175% Params, 4.82 MMac, 1.504% MACs, 192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, 0.002% Params, 50.18 KMac, 0.016% MACs, 32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (6): InvertedResidual(
#       14.85 k, 0.424% Params, 11.94 MMac, 3.729% MACs,
#       (conv): Sequential(
#         14.85 k, 0.424% Params, 11.94 MMac, 3.729% MACs,
#         (0): Conv2dNormActivation(
#           6.53 k, 0.186% Params, 5.27 MMac, 1.645% MACs,
#           (0): Conv2d(6.14 k, 0.175% Params, 4.82 MMac, 1.504% MACs, 32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, 0.011% Params, 301.06 KMac, 0.094% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(0, 0.000% Params, 150.53 KMac, 0.047% MACs, inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           2.11 k, 0.060% Params, 1.81 MMac, 0.564% MACs,
#           (0): Conv2d(1.73 k, 0.049% Params, 1.35 MMac, 0.423% MACs, 192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#           (1): BatchNorm2d(384, 0.011% Params, 301.06 KMac, 0.094% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(0, 0.000% Params, 150.53 KMac, 0.047% MACs, inplace=True)
#         )
#         (2): Conv2d(6.14 k, 0.175% Params, 4.82 MMac, 1.504% MACs, 192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, 0.002% Params, 50.18 KMac, 0.016% MACs, 32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (7): InvertedResidual(
#       21.06 k, 0.601% Params, 8.15 MMac, 2.546% MACs,
#       (conv): Sequential(
#         21.06 k, 0.601% Params, 8.15 MMac, 2.546% MACs,
#         (0): Conv2dNormActivation(
#           6.53 k, 0.186% Params, 5.27 MMac, 1.645% MACs,
#           (0): Conv2d(6.14 k, 0.175% Params, 4.82 MMac, 1.504% MACs, 32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, 0.011% Params, 301.06 KMac, 0.094% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(0, 0.000% Params, 150.53 KMac, 0.047% MACs, inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           2.11 k, 0.060% Params, 451.58 KMac, 0.141% MACs,
#           (0): Conv2d(1.73 k, 0.049% Params, 338.69 KMac, 0.106% MACs, 192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=192, bias=False)
#           (1): BatchNorm2d(384, 0.011% Params, 75.26 KMac, 0.024% MACs, 192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(0, 0.000% Params, 37.63 KMac, 0.012% MACs, inplace=True)
#         )
#         (2): Conv2d(12.29 k, 0.351% Params, 2.41 MMac, 0.752% MACs, 192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(128, 0.004% Params, 25.09 KMac, 0.008% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (8): InvertedResidual(
#       54.27 k, 1.548% Params, 10.79 MMac, 3.369% MACs,
#       (conv): Sequential(
#         54.27 k, 1.548% Params, 10.79 MMac, 3.369% MACs,
#         (0): Conv2dNormActivation(
#           25.34 k, 0.723% Params, 5.04 MMac, 1.575% MACs,
#           (0): Conv2d(24.58 k, 0.701% Params, 4.82 MMac, 1.504% MACs, 64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(768, 0.022% Params, 150.53 KMac, 0.047% MACs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(0, 0.000% Params, 75.26 KMac, 0.024% MACs, inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           4.22 k, 0.121% Params, 903.17 KMac, 0.282% MACs,
#           (0): Conv2d(3.46 k, 0.099% Params, 677.38 KMac, 0.212% MACs, 384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(768, 0.022% Params, 150.53 KMac, 0.047% MACs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(0, 0.000% Params, 75.26 KMac, 0.024% MACs, inplace=True)
#         )
#         (2): Conv2d(24.58 k, 0.701% Params, 4.82 MMac, 1.504% MACs, 384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(128, 0.004% Params, 25.09 KMac, 0.008% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (9): InvertedResidual(
#       54.27 k, 1.548% Params, 10.79 MMac, 3.369% MACs,
#       (conv): Sequential(
#         54.27 k, 1.548% Params, 10.79 MMac, 3.369% MACs,
#         (0): Conv2dNormActivation(
#           25.34 k, 0.723% Params, 5.04 MMac, 1.575% MACs,
#           (0): Conv2d(24.58 k, 0.701% Params, 4.82 MMac, 1.504% MACs, 64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(768, 0.022% Params, 150.53 KMac, 0.047% MACs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(0, 0.000% Params, 75.26 KMac, 0.024% MACs, inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           4.22 k, 0.121% Params, 903.17 KMac, 0.282% MACs,
#           (0): Conv2d(3.46 k, 0.099% Params, 677.38 KMac, 0.212% MACs, 384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(768, 0.022% Params, 150.53 KMac, 0.047% MACs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(0, 0.000% Params, 75.26 KMac, 0.024% MACs, inplace=True)
#         )
#         (2): Conv2d(24.58 k, 0.701% Params, 4.82 MMac, 1.504% MACs, 384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(128, 0.004% Params, 25.09 KMac, 0.008% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (10): InvertedResidual(
#       54.27 k, 1.548% Params, 10.79 MMac, 3.369% MACs,
#       (conv): Sequential(
#         54.27 k, 1.548% Params, 10.79 MMac, 3.369% MACs,
#         (0): Conv2dNormActivation(
#           25.34 k, 0.723% Params, 5.04 MMac, 1.575% MACs,
#           (0): Conv2d(24.58 k, 0.701% Params, 4.82 MMac, 1.504% MACs, 64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(768, 0.022% Params, 150.53 KMac, 0.047% MACs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(0, 0.000% Params, 75.26 KMac, 0.024% MACs, inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           4.22 k, 0.121% Params, 903.17 KMac, 0.282% MACs,
#           (0): Conv2d(3.46 k, 0.099% Params, 677.38 KMac, 0.212% MACs, 384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(768, 0.022% Params, 150.53 KMac, 0.047% MACs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(0, 0.000% Params, 75.26 KMac, 0.024% MACs, inplace=True)
#         )
#         (2): Conv2d(24.58 k, 0.701% Params, 4.82 MMac, 1.504% MACs, 384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(128, 0.004% Params, 25.09 KMac, 0.008% MACs, 64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (11): InvertedResidual(
#       66.62 k, 1.901% Params, 13.21 MMac, 4.125% MACs,
#       (conv): Sequential(
#         66.62 k, 1.901% Params, 13.21 MMac, 4.125% MACs,
#         (0): Conv2dNormActivation(
#           25.34 k, 0.723% Params, 5.04 MMac, 1.575% MACs,
#           (0): Conv2d(24.58 k, 0.701% Params, 4.82 MMac, 1.504% MACs, 64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(768, 0.022% Params, 150.53 KMac, 0.047% MACs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(0, 0.000% Params, 75.26 KMac, 0.024% MACs, inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           4.22 k, 0.121% Params, 903.17 KMac, 0.282% MACs,
#           (0): Conv2d(3.46 k, 0.099% Params, 677.38 KMac, 0.212% MACs, 384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(768, 0.022% Params, 150.53 KMac, 0.047% MACs, 384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(0, 0.000% Params, 75.26 KMac, 0.024% MACs, inplace=True)
#         )
#         (2): Conv2d(36.86 k, 1.052% Params, 7.23 MMac, 2.256% MACs, 384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(192, 0.005% Params, 37.63 KMac, 0.012% MACs, 96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (12): InvertedResidual(
#       118.27 k, 3.375% Params, 23.41 MMac, 7.309% MACs,
#       (conv): Sequential(
#         118.27 k, 3.375% Params, 23.41 MMac, 7.309% MACs,
#         (0): Conv2dNormActivation(
#           56.45 k, 1.611% Params, 11.18 MMac, 3.490% MACs,
#           (0): Conv2d(55.3 k, 1.578% Params, 10.84 MMac, 3.384% MACs, 96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1.15 k, 0.033% Params, 225.79 KMac, 0.071% MACs, 576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(0, 0.000% Params, 112.9 KMac, 0.035% MACs, inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           6.34 k, 0.181% Params, 1.35 MMac, 0.423% MACs,
#           (0): Conv2d(5.18 k, 0.148% Params, 1.02 MMac, 0.317% MACs, 576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#           (1): BatchNorm2d(1.15 k, 0.033% Params, 225.79 KMac, 0.071% MACs, 576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(0, 0.000% Params, 112.9 KMac, 0.035% MACs, inplace=True)
#         )
#         (2): Conv2d(55.3 k, 1.578% Params, 10.84 MMac, 3.384% MACs, 576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(192, 0.005% Params, 37.63 KMac, 0.012% MACs, 96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (13): InvertedResidual(
#       118.27 k, 3.375% Params, 23.41 MMac, 7.309% MACs,
#       (conv): Sequential(
#         118.27 k, 3.375% Params, 23.41 MMac, 7.309% MACs,
#         (0): Conv2dNormActivation(
#           56.45 k, 1.611% Params, 11.18 MMac, 3.490% MACs,
#           (0): Conv2d(55.3 k, 1.578% Params, 10.84 MMac, 3.384% MACs, 96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1.15 k, 0.033% Params, 225.79 KMac, 0.071% MACs, 576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(0, 0.000% Params, 112.9 KMac, 0.035% MACs, inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           6.34 k, 0.181% Params, 1.35 MMac, 0.423% MACs,
#           (0): Conv2d(5.18 k, 0.148% Params, 1.02 MMac, 0.317% MACs, 576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#           (1): BatchNorm2d(1.15 k, 0.033% Params, 225.79 KMac, 0.071% MACs, 576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(0, 0.000% Params, 112.9 KMac, 0.035% MACs, inplace=True)
#         )
#         (2): Conv2d(55.3 k, 1.578% Params, 10.84 MMac, 3.384% MACs, 576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(192, 0.005% Params, 37.63 KMac, 0.012% MACs, 96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (14): InvertedResidual(
#       155.26 k, 4.430% Params, 16.05 MMac, 5.011% MACs,
#       (conv): Sequential(
#         155.26 k, 4.430% Params, 16.05 MMac, 5.011% MACs,
#         (0): Conv2dNormActivation(
#           56.45 k, 1.611% Params, 11.18 MMac, 3.490% MACs,
#           (0): Conv2d(55.3 k, 1.578% Params, 10.84 MMac, 3.384% MACs, 96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1.15 k, 0.033% Params, 225.79 KMac, 0.071% MACs, 576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(0, 0.000% Params, 112.9 KMac, 0.035% MACs, inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           6.34 k, 0.181% Params, 338.69 KMac, 0.106% MACs,
#           (0): Conv2d(5.18 k, 0.148% Params, 254.02 KMac, 0.079% MACs, 576, 576, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=576, bias=False)
#           (1): BatchNorm2d(1.15 k, 0.033% Params, 56.45 KMac, 0.018% MACs, 576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(0, 0.000% Params, 28.22 KMac, 0.009% MACs, inplace=True)
#         )
#         (2): Conv2d(92.16 k, 2.629% Params, 4.52 MMac, 1.410% MACs, 576, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(320, 0.009% Params, 15.68 KMac, 0.005% MACs, 160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (15): InvertedResidual(
#       320.0 k, 9.130% Params, 15.77 MMac, 4.926% MACs,
#       (conv): Sequential(
#         320.0 k, 9.130% Params, 15.77 MMac, 4.926% MACs,
#         (0): Conv2dNormActivation(
#           155.52 k, 4.437% Params, 7.67 MMac, 2.394% MACs,
#           (0): Conv2d(153.6 k, 4.382% Params, 7.53 MMac, 2.350% MACs, 160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1.92 k, 0.055% Params, 94.08 KMac, 0.029% MACs, 960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(0, 0.000% Params, 47.04 KMac, 0.015% MACs, inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           10.56 k, 0.301% Params, 564.48 KMac, 0.176% MACs,
#           (0): Conv2d(8.64 k, 0.247% Params, 423.36 KMac, 0.132% MACs, 960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(1.92 k, 0.055% Params, 94.08 KMac, 0.029% MACs, 960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(0, 0.000% Params, 47.04 KMac, 0.015% MACs, inplace=True)
#         )
#         (2): Conv2d(153.6 k, 4.382% Params, 7.53 MMac, 2.350% MACs, 960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(320, 0.009% Params, 15.68 KMac, 0.005% MACs, 160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (16): InvertedResidual(
#       320.0 k, 9.130% Params, 15.77 MMac, 4.926% MACs,
#       (conv): Sequential(
#         320.0 k, 9.130% Params, 15.77 MMac, 4.926% MACs,
#         (0): Conv2dNormActivation(
#           155.52 k, 4.437% Params, 7.67 MMac, 2.394% MACs,
#           (0): Conv2d(153.6 k, 4.382% Params, 7.53 MMac, 2.350% MACs, 160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1.92 k, 0.055% Params, 94.08 KMac, 0.029% MACs, 960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(0, 0.000% Params, 47.04 KMac, 0.015% MACs, inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           10.56 k, 0.301% Params, 564.48 KMac, 0.176% MACs,
#           (0): Conv2d(8.64 k, 0.247% Params, 423.36 KMac, 0.132% MACs, 960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(1.92 k, 0.055% Params, 94.08 KMac, 0.029% MACs, 960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(0, 0.000% Params, 47.04 KMac, 0.015% MACs, inplace=True)
#         )
#         (2): Conv2d(153.6 k, 4.382% Params, 7.53 MMac, 2.350% MACs, 960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(320, 0.009% Params, 15.68 KMac, 0.005% MACs, 160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (17): InvertedResidual(
#       473.92 k, 13.522% Params, 23.32 MMac, 7.281% MACs,
#       (conv): Sequential(
#         473.92 k, 13.522% Params, 23.32 MMac, 7.281% MACs,
#         (0): Conv2dNormActivation(
#           155.52 k, 4.437% Params, 7.67 MMac, 2.394% MACs,
#           (0): Conv2d(153.6 k, 4.382% Params, 7.53 MMac, 2.350% MACs, 160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1.92 k, 0.055% Params, 94.08 KMac, 0.029% MACs, 960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(0, 0.000% Params, 47.04 KMac, 0.015% MACs, inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           10.56 k, 0.301% Params, 564.48 KMac, 0.176% MACs,
#           (0): Conv2d(8.64 k, 0.247% Params, 423.36 KMac, 0.132% MACs, 960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(1.92 k, 0.055% Params, 94.08 KMac, 0.029% MACs, 960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(0, 0.000% Params, 47.04 KMac, 0.015% MACs, inplace=True)
#         )
#         (2): Conv2d(307.2 k, 8.765% Params, 15.05 MMac, 4.701% MACs, 960, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(640, 0.018% Params, 31.36 KMac, 0.010% MACs, 320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (18): Conv2dNormActivation(
#       412.16 k, 11.760% Params, 20.26 MMac, 6.326% MACs,
#       (0): Conv2d(409.6 k, 11.687% Params, 20.07 MMac, 6.267% MACs, 320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(2.56 k, 0.073% Params, 125.44 KMac, 0.039% MACs, 1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(0, 0.000% Params, 62.72 KMac, 0.020% MACs, inplace=True)
#     )
#   )
#   (classifier): Sequential(
#     1.28 M, 36.549% Params, 1.28 MMac, 0.400% MACs,
#     (0): Dropout(0, 0.000% Params, 0.0 Mac, 0.000% MACs, p=0.2, inplace=False)
#     (1): Linear(1.28 M, 36.549% Params, 1.28 MMac, 0.400% MACs, in_features=1280, out_features=1000, bias=True)
#   )
# )
# Computational complexity:       320.24 MMac
# Number of parameters:           3.5 M
